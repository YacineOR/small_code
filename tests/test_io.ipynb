# %%
import smallcode as sc
import xarray as xr

# %%
sc.read_data('../data/cds_monthly_t2m_ssr_1940-present.nc')
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 721, expver: 2, time: 1003)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * expver     (expver) int32 1 5
#   * time       (time) datetime64[ns] 1940-01-01 1940-02-01 ... 2023-07-01
# Data variables:
#     t2m        (time, expver, latitude, longitude) float32 ...
#     ssr        (time, expver, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-08-28 10:41:01 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
sc.read_data('../data/cds_monthly_t2m_ssr_1940-present.nc', timespan=("1980-01","2022-12"), expver=1)
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 721, time: 516)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#     expver     int32 1
#   * time       (time) datetime64[ns] 1980-01-01 1980-02-01 ... 2022-12-01
# Data variables:
#     t2m        (time, latitude, longitude) float32 ...
#     ssr        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-08-28 10:41:01 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
temp = sc.read_data('../data/cds_monthly_t2m_ssr_1940-present.nc', darrays=['t2m'], timespan=("1990-01","2023-07"), expver=1)
display(temp)
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 403, latitude: 721, longitude: 1440)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#     expver     int32 1
#   * time       (time) datetime64[ns] 1990-01-01 1990-02-01 ... 2023-07-01
# Data variables:
#     t2m        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-08-28 10:41:01 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
sc.write_data(temp,'write_data_temp_1990-present.nc')

# %%
temp2 = sc.read_data('write_data_temp_1990-present.nc')
xr.testing.assert_equal(temp,temp2)

# %%
# !rm write_data_temp_1990-present.nc
