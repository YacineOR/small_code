# %%
import smallcode as sc
import xarray as xr

# %%
data = sc.read_data('../data/cds_monthly_t2m_ssr_1940-present.nc', timespan=("2013-01","2022-12"), expver=1)
sc.kelvin_to_celsius(data, 't2m')
data = sc.center_longitude0(data)

# %%
sc.plot_monthly_means(data["t2m"])

# %%
sc.plot_yearly_means(data["t2m"])
